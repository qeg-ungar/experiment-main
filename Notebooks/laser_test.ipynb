# %%
laser_control = dlnsec_laser

# %%
laser_control.get_power()
# Out:
# 11.0

# %%
laser_control.off();

# %%
laser_control.get_trigger_mode()
# Out:
# <TriggerMode.LAS: 0>

# %%
laser_control.get_laser_state()
# Out:
# <LaserState.OFF: 0>

# %%
laser_control.set_power(10)

# %%
laser_control.on()
# Out:
# <LaserState.ON: 1>

# %%
laser_control.get_power()
# Out:
# 11.0

# %%
1+1
# Out:
# 2
