# %%
import matplotlib.pyplot as plt
import numpy as np
spad = camera_SPC3experiment-main/Notebooks/SPAD_test_snap.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 spad = camera_SPC3
#
# NameError: name 'camera_SPC3' is not defined

# %%
spad._NFrames = 1 
spad._apply_camera_settings()

# %%
snap = spad.start_single_acquisition()

# %%
# Get frames from snap
frame = np.array(snap[0, 0, :, :])
#align upper left corner to correspond to image orientation
plt.imshow(np.flipud(frame))
plt.colorbar()
plt.title('SPAD Snapshot Frame')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Get frames from snap
# ----> 2 frame = np.array(snap[0, 0, :, :])
#       3 #align upper left corner to correspond to image orientation
#       4 plt.imshow(np.flipud(frame))
#
# TypeError: 'NoneType' object is not subscriptable
